# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
population_df = pd.read_csv("../Resources/NST-EST2021-alldata.csv", encoding="latin-1")
population_df.head(10)
# Out:
#    SUMLEV REGION DIVISION  STATE              NAME  ESTIMATESBASE2020
# 0      10      0        0      0     United States          331449281  \
# 1      20      1        0      0  Northeast Region           57609148
# 2      20      2        0      0    Midwest Region           68985454
# 3      20      3        0      0      South Region          126266107
# 4      20      4        0      0       West Region           78588572
# 5      40      3        6      1           Alabama            5024279
# 6      40      4        9      2            Alaska             733391
# 7      40      4        8      4           Arizona            7151502
# 8      40      3        7      5          Arkansas            3011524
# 9      40      4        9      6        California           39538223
#
#    POPESTIMATE2020  POPESTIMATE2021  NPOPCHG_2020  NPOPCHG_2021  ...
# 0        331501080        331893745         51799        392665  ...  \
# ...

# %%
database_path = ("../SQLiteDatabase/Accidents_2021.db")
engine = create_engine(f"sqlite:///{database_path}")
conn = engine.connect()

# %%
population_df.to_sql("population", conn, schema=None, if_exists='append', index=False, index_label=None, chunksize=None, dtype=None, method=None)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\base.py:1934, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1933     if not evt_handled:
# -> 1934         self.dialect.do_executemany(
#    1935             cursor,
#    1936             str_statement,
#    1937             effective_parameters,
#    1938             context,
#    1939         )
#    1940 elif not effective_parameters and context.no_parameters:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\default.py:918, in DefaultDialect.do_executemany(self, cursor, statement, parameters, context)
# ...
